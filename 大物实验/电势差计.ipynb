# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
x1 = np.concatenate((np.arange(0,11,5),np.arange(20,161,10),np.arange(180,201,20),np.arange(300,1001,100),np.arange(1200,1801,200)))
y1 =np.array([0,12,31,60,84,102,117,129,140,150,157,165,171,177,183,188,192,197,204,212,239,258,272,284,294,302,309,315,325,333,340,346])
x1.shape,y1.shape
# Out:
# ((32,), (32,))

# %%
plt.figure(figsize=(10,6))
plt.xlabel("I D")
plt.ylabel("Voc")
plt.title("I D ~ Voc")
x1_ticks = np.arange(0,1801,100)
plt.xticks(x1_ticks)
plt.plot(x1,y1,ls="-")

# %%
x2 = np.concatenate((np.arange(100,201,50),np.arange(300,801,100),np.arange(1000,1601,200)))
y2 = np.array([1.1976,1.8349,2.5316,3.7879,5.1546,6.4935,7.8125,9.0909,10.559,13.297,16.105,19.087,21.687])
x2.shape, y2.shape
# Out:
# ((13,), (13,))

# %%
plt.figure(figsize=(10,6))
plt.xlabel("I D")
plt.ylabel("Isc")
plt.title("I D ~ Isc")
x1_ticks = np.arange(0,1601,100)
plt.xticks(x1_ticks)
plt.plot(x2,y2,ls="-")

# %%
x3 = x2
y3 = np.array([137.78,104.64,83.742,63.096,50.052,41.888,36.352,32.340,28.602,23.690,20.180,17.446,15.678])
x3.shape,y3.shape
# Out:
# ((13,), (13,))

# %%
plt.figure(figsize=(10,6))
plt.xlabel("I D")
plt.ylabel("Ri")
plt.title("I D ~ Ri")
x1_ticks = np.arange(0,1601,100)
plt.xticks(x1_ticks)
plt.plot(x3,y3,ls="-")

# %%
x4 = np.array([121.4,168.9,202.4,225.3,240.0,251.3,259.2,270.0,277.2,282.1,285.6,288.9,291.5,297.6,300.3,301.6,300.7,303.4,300.9,300.0,300.2,300.7,300.3])
y4 = np.array([12.14,11.26,10.12,9.01,8.00,7.18,6.48,5.40,4.62,4.03,3.57,3.21,2.65,1.86,1.43,1.16,0.97,0.74,0.59,0.50,0.42,0.37,0.33])
x4.shape,y4.shape
# Out:
# ((23,), (23,))

# %%
plt.figure(figsize=(10,6))
plt.xlabel("V L")
plt.ylabel("I L")
plt.title("I L ~ V L")

plt.plot(x4,y4,ls="-")

# %%
x5 = np.concatenate((np.arange(0,31,5),np.arange(40,81,10),np.arange(100,301,50),np.arange(400,901,100)))+10
y5 = np.array([1473,1902,2048,2030,1920,1804,1680,1458,1280,1128,1020,927.7,772.5,553.5,429.4,349.8,261.7,224.5,180.6,152.5,125.2,110.9,99.10])
x5.shape,y5.shape
# Out:
# ((23,), (23,))

# %%
plt.figure(figsize=(10,6))
plt.xlabel("R L")
plt.ylabel("P")
plt.title("P ~ R L")
x1_ticks = np.arange(10,911,100)
plt.xticks(x1_ticks)
plt.plot(x5,y5,ls="-")
